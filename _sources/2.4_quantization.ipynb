# %%
# !apt-get  -qq  install  -y  graphviz  &&  pip  install  pydot
# !pip  install  -U  matplotlib
# !pip  install  git+https://github.com/fastmachinelearning/hls4ml.git@main#egg=hls4ml[profiling]
# !pip  install  qkeras==0.9.0
# Out:
# /bin/bash: apt-get: command not found
# Requirement already satisfied: matplotlib in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (3.5.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: six>=1.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting hls4ml[profiling]
#   Cloning https://github.com/fastmachinelearning/hls4ml.git (to revision main) to /private/var/folders/3l/14rcjzxj1t3gv_xqt_53y5yw0000gn/T/pip-install-wfmaxt0a/hls4ml_3f31ee5f9e514e74a7b851298b707547
#   Running command git clone --filter=blob:none --quiet https://github.com/fastmachinelearning/hls4ml.git /private/var/folders/3l/14rcjzxj1t3gv_xqt_53y5yw0000gn/T/pip-install-wfmaxt0a/hls4ml_3f31ee5f9e514e74a7b851298b707547
#   Resolved https://github.com/fastmachinelearning/hls4ml.git to commit 62046d799a4dbec150addc7f78fea5b579efeda1
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.23.1)
# Requirement already satisfied: six in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.16.0)
# Requirement already satisfied: pyyaml in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (6.0)
# Requirement already satisfied: h5py in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (3.7.0)
# Requirement already satisfied: onnx>=1.4.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.12.0)
# Requirement already satisfied: calmjs.parse in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.3.0)
# Requirement already satisfied: tabulate in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (0.8.10)
# Requirement already satisfied: pydigitalwavetools==1.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.1)
# Requirement already satisfied: qkeras in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (0.9.0)
# Requirement already satisfied: pandas in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (1.4.3)
# Requirement already satisfied: seaborn in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (0.11.2)
# Requirement already satisfied: matplotlib in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from hls4ml[profiling]) (3.5.2)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from onnx>=1.4.0->hls4ml[profiling]) (4.3.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from onnx>=1.4.0->hls4ml[profiling]) (3.20.1)
# Requirement already satisfied: setuptools in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from calmjs.parse->hls4ml[profiling]) (63.2.0)
# Requirement already satisfied: ply>=3.6 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from calmjs.parse->hls4ml[profiling]) (3.11)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from matplotlib->hls4ml[profiling]) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pandas->hls4ml[profiling]) (2022.1)
# Requirement already satisfied: pyparser in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (1.0)
# Requirement already satisfied: keras-tuner>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (1.1.3)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (4.64.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (0.7.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (1.8.1)
# Requirement already satisfied: scikit-learn>=0.23.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (1.1.1)
# Requirement already satisfied: networkx>=2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras->hls4ml[profiling]) (2.8.5)
# Requirement already satisfied: requests in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.28.1)
# Requirement already satisfied: tensorboard in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.9.0)
# Requirement already satisfied: kt-legacy in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.0.4)
# Requirement already satisfied: ipython in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (8.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from scikit-learn>=0.23.1->qkeras->hls4ml[profiling]) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from scikit-learn>=0.23.1->qkeras->hls4ml[profiling]) (1.1.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.2.1->qkeras->hls4ml[profiling]) (0.1.7)
# Requirement already satisfied: parse==1.6.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pyparser->qkeras->hls4ml[profiling]) (1.6.5)
# Requirement already satisfied: stack-data in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.3.0)
# Requirement already satisfied: traitlets>=5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (5.3.0)
# Requirement already satisfied: appnope in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.1.3)
# Requirement already satisfied: backcall in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (3.0.30)
# Requirement already satisfied: pexpect>4.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.12.0)
# Requirement already satisfied: jedi>=0.16 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.7.5)
# Requirement already satisfied: decorator in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (5.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2022.6.15)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.6.0)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.46.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.9.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.2.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from jedi>=0.16->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (4.11.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pexpect>4.3->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.1.1)
# Requirement already satisfied: executing in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.9.1)
# Requirement already satisfied: asttokens in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.2.2)
# Requirement already satisfied: zipp>=0.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.1->qkeras->hls4ml[profiling]) (3.2.0)
# Requirement already satisfied: qkeras==0.9.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.16.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (1.23.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (0.7.3)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (4.64.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (1.8.1)
# Requirement already satisfied: scikit-learn>=0.23.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (1.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (63.2.0)
# Requirement already satisfied: networkx>=2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (2.8.5)
# Requirement already satisfied: keras-tuner>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (1.1.3)
# Requirement already satisfied: pyparser in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from qkeras==0.9.0) (1.0)
# Requirement already satisfied: requests in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras==0.9.0) (2.28.1)
# Requirement already satisfied: ipython in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras==0.9.0) (8.4.0)
# Requirement already satisfied: packaging in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras==0.9.0) (21.3)
# Requirement already satisfied: kt-legacy in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras==0.9.0) (1.0.4)
# Requirement already satisfied: tensorboard in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from keras-tuner>=1.0.1->qkeras==0.9.0) (2.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from scikit-learn>=0.23.1->qkeras==0.9.0) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from scikit-learn>=0.23.1->qkeras==0.9.0) (1.1.0)
# Requirement already satisfied: six~=1.10 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.2.1->qkeras==0.9.0) (1.16.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.2.1->qkeras==0.9.0) (0.1.7)
# Requirement already satisfied: parse==1.6.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pyparser->qkeras==0.9.0) (1.6.5)
# Requirement already satisfied: decorator in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.18.1)
# Requirement already satisfied: traitlets>=5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (5.3.0)
# Requirement already satisfied: pexpect>4.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (4.8.0)
# Requirement already satisfied: stack-data in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.3.0)
# Requirement already satisfied: pickleshare in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.7.5)
# Requirement already satisfied: appnope in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.1.3)
# Requirement already satisfied: backcall in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (2.12.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (3.0.30)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from packaging->keras-tuner>=1.0.1->qkeras==0.9.0) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras==0.9.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras==0.9.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras==0.9.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests->keras-tuner>=1.0.1->qkeras==0.9.0) (2022.6.15)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (2.9.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (3.4.1)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (3.20.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (2.2.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (0.6.0)
# Requirement already satisfied: wheel>=0.26 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (0.37.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from jedi>=0.16->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (4.11.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pexpect>4.3->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (2.1.1)
# Requirement already satisfied: executing in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.9.1)
# Requirement already satisfied: pure-eval in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (0.2.2)
# Requirement already satisfied: asttokens in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from stack-data->ipython->keras-tuner>=1.0.1->qkeras==0.9.0) (2.0.5)
# Requirement already satisfied: zipp>=0.5 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.0.1->qkeras==0.9.0) (3.2.0)

# %%
COLAB=True

# %%
# !pip install wget
import wget
import os.path
# WGET for colab
if not os.path.exists("callbacks.py"):
    url = "https://raw.githubusercontent.com/jmduarte/iaifi-summer-school/main/book/callbacks.py"
    callbacksFile = wget.download(url)
if not os.path.exists("plotting.py"):
    urlPlot = "https://raw.githubusercontent.com/jmduarte/iaifi-summer-school/main/book/plotting.py"
    plotFile = wget.download(urlPlot)

# %%
if COLAB:
    if not os.path.exists("./iaifi-summer-school"):
        # !git clone https://github.com/jmduarte/iaifi-summer-school.git

# %% [markdown]
# # Quantization

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
# import os
# os.environ['PATH'] = '/opt/Xilinx/Vivado/2019.2/bin:' + os.environ['PATH']
# for this tutorial we wont be actually running Vivado, so I have commented these lines out
#     but if you want to look into actually running on an FPGA then simply uncomment these lines

if not COLAB:
    #FOR LOCAL PULL
    X_train_val = np.load("X_train_val.npy")
    X_test = np.load("X_test.npy")
    y_train_val = np.load("y_train_val.npy")
    y_test = np.load("y_test.npy")
    classes = np.load("classes.npy", allow_pickle=True)

if COLAB:
    #FOR COLAB
    X_train_val = np.load("iaifi-summer-school/book/X_train_val.npy")
    X_test = np.load("iaifi-summer-school/book/X_test.npy")
    y_train_val = np.load("iaifi-summer-school/book/y_train_val.npy")
    y_test = np.load("iaifi-summer-school/book/y_test.npy")
    classes = np.load("iaifi-summer-school/book/classes.npy", allow_pickle=True)

# %% [markdown]
# ## Construct a new model
# This time we're going to use QKeras layers.
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models, maintained by Google.
#
# https://github.com/google/qkeras
#
# The convenient thing here is that the QKeras layers can be used as drop-in replacements for the corresponding Keras layers.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %% [markdown]
# We're using `QDense` layer instead of `Dense`, and `QActivation` instead of `Activation`. We're also specifying `kernel_quantizer = quantized_bits(6,0,...)`. This will use 6-bits (of which 0 are integer) for the weights. We also use the same quantization for the biases, and `quantized_relu(6)` for 6-bit ReLU activations.

# %%
model = Sequential()
model.add(
    QDense(
        64,
        input_shape=(16,),
        name="fc1",
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer="lecun_uniform",
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name="relu1"))
model.add(
    QDense(
        32,
        name="fc2",
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer="lecun_uniform",
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name="relu2"))
model.add(
    QDense(
        32,
        name="fc3",
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer="lecun_uniform",
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(6), name="relu3"))
model.add(
    QDense(
        5,
        name="output",
        kernel_quantizer=quantized_bits(6, 0, alpha=1),
        bias_quantizer=quantized_bits(6, 0, alpha=1),
        kernel_initializer="lecun_uniform",
        kernel_regularizer=l1(0.0001),
    )
)
model.add(Activation(activation="softmax", name="softmax"))
# Out:
# 2022-08-01 21:15:59.198655: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Train sparse
# Let's train with model sparsity again, since QKeras layers are also prunable.

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import (
    prune,
    pruning_callbacks,
    pruning_schedule,
)
from tensorflow_model_optimization.sparsity.keras import strip_pruning

pruning_params = {
    "pruning_schedule": pruning_schedule.ConstantSparsity(
        0.75, begin_step=2000, frequency=100
    )
}
model = prune.prune_low_magnitude(model, **pruning_params)

# %% [markdown]
# ## Train the model
# We'll use the same settings as the original model: Adam optimizer with categorical crossentropy loss.
# The callbacks will decay the learning rate and save the model into a directory 'model_5'
# The model isn't very complex, so this should just take a few minutes even on the CPU.
# If you've restarted the notebook kernel after training once, set `train = False` to load the trained model rather than training again.

# %%
train = True
if train:
    adam = Adam(lr=0.0001)
    model.compile(
        optimizer=adam, loss=["categorical_crossentropy"], metrics=["accuracy"]
    )
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir="model_5",
    )
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(
        X_train_val,
        y_train_val,
        batch_size=1024,
        epochs=30,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save("model_5/KERAS_check_best_model.h5")
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects

    co = {}
    _add_supported_quantized_objects(co)
    model = load_model("model_5/KERAS_check_best_model.h5", custom_objects=co)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/30
# /Users/wmccorma/miniconda3/envs/ml-iaifi/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#   1/487 [..............................] - ETA: 20:50 - loss: 1.6368 - accuracy: 0.3262WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0035s vs `on_train_batch_end` time: 0.0058s). Check your callbacks.
# 477/487 [============================>.] - ETA: 0s - loss: 1.3893 - accuracy: 0.4893
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 1: val_loss improved from inf to 1.19395, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 1.19395, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 1: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 5s 5ms/step - loss: 1.3854 - accuracy: 0.4916 - val_loss: 1.1940 - val_accuracy: 0.6129 - lr: 1.0000e-04
# Epoch 2/30
# 474/487 [============================>.] - ETA: 0s - loss: 1.1096 - accuracy: 0.6522
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 2: val_loss improved from 1.19395 to 1.04657, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 2: val_loss improved from 1.19395 to 1.04657, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 2: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 5ms/step - loss: 1.1079 - accuracy: 0.6529 - val_loss: 1.0466 - val_accuracy: 0.6832 - lr: 1.0000e-04
# Epoch 3/30
# 486/487 [============================>.] - ETA: 0s - loss: 1.0008 - accuracy: 0.7014
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 3: val_loss improved from 1.04657 to 0.96324, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 3: val_loss improved from 1.04657 to 0.96324, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 3: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.0008 - accuracy: 0.7014 - val_loss: 0.9632 - val_accuracy: 0.7125 - lr: 1.0000e-04
# Epoch 4/30
# 479/487 [============================>.] - ETA: 0s - loss: 0.9311 - accuracy: 0.7176
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 4: val_loss improved from 0.96324 to 0.90714, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 4: val_loss improved from 0.96324 to 0.90714, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 4: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.9308 - accuracy: 0.7175 - val_loss: 0.9071 - val_accuracy: 0.7217 - lr: 1.0000e-04
# Epoch 5/30
# 485/487 [============================>.] - ETA: 0s - loss: 1.1100 - accuracy: 0.6642
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 5: val_loss did not improve from 0.90714
#
# Epoch 5: val_loss did not improve from 0.90714
#
# Epoch 5: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 5: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.1099 - accuracy: 0.6643 - val_loss: 1.0583 - val_accuracy: 0.6908 - lr: 1.0000e-04
# Epoch 6/30
# 482/487 [============================>.] - ETA: 0s - loss: 1.0145 - accuracy: 0.7012
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 6: val_loss did not improve from 0.90714
#
# Epoch 6: val_loss did not improve from 0.90714
#
# Epoch 6: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 6: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 1.0142 - accuracy: 0.7013 - val_loss: 0.9864 - val_accuracy: 0.7071 - lr: 1.0000e-04
# Epoch 7/30
# 484/487 [============================>.] - ETA: 0s - loss: 0.9584 - accuracy: 0.7115
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 7: val_loss did not improve from 0.90714
#
# Epoch 7: val_loss did not improve from 0.90714
#
# Epoch 7: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 7: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.9583 - accuracy: 0.7115 - val_loss: 0.9409 - val_accuracy: 0.7147 - lr: 1.0000e-04
# Epoch 8/30
# 478/487 [============================>.] - ETA: 0s - loss: 0.9227 - accuracy: 0.7166
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 8: val_loss did not improve from 0.90714
#
# Epoch 8: val_loss did not improve from 0.90714
#
# Epoch 8: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 8: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.9223 - accuracy: 0.7169 - val_loss: 0.9106 - val_accuracy: 0.7185 - lr: 1.0000e-04
# Epoch 9/30
# 474/487 [============================>.] - ETA: 0s - loss: 0.8966 - accuracy: 0.7203
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 9: val_loss improved from 0.90714 to 0.88776, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 9: val_loss improved from 0.90714 to 0.88776, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 9: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8963 - accuracy: 0.7203 - val_loss: 0.8878 - val_accuracy: 0.7212 - lr: 1.0000e-04
# Epoch 10/30
# 473/487 [============================>.] - ETA: 0s - loss: 0.8750 - accuracy: 0.7234
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 10: val_loss improved from 0.88776 to 0.86828, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 10: val_loss improved from 0.88776 to 0.86828, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 10: saving model to model_5/KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model_5/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8749 - accuracy: 0.7233 - val_loss: 0.8683 - val_accuracy: 0.7241 - lr: 1.0000e-04
# Epoch 11/30
# 480/487 [============================>.] - ETA: 0s - loss: 0.8570 - accuracy: 0.7259
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 11: val_loss improved from 0.86828 to 0.85192, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 11: val_loss improved from 0.86828 to 0.85192, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 11: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8568 - accuracy: 0.7260 - val_loss: 0.8519 - val_accuracy: 0.7263 - lr: 1.0000e-04
# Epoch 12/30
# 487/487 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.7285
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 12: val_loss improved from 0.85192 to 0.83642, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 12: val_loss improved from 0.85192 to 0.83642, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 12: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8409 - accuracy: 0.7285 - val_loss: 0.8364 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 13/30
# 479/487 [============================>.] - ETA: 0s - loss: 0.8276 - accuracy: 0.7308
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 13: val_loss improved from 0.83642 to 0.82485, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 13: val_loss improved from 0.83642 to 0.82485, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model_5/KERAS_check_model_last.h5
# Epoch 13: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8274 - accuracy: 0.7307 - val_loss: 0.8248 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 14/30
# 482/487 [============================>.] - ETA: 0s - loss: 0.8161 - accuracy: 0.7328
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 14: val_loss improved from 0.82485 to 0.81395, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 14: val_loss improved from 0.82485 to 0.81395, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 14: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8161 - accuracy: 0.7328 - val_loss: 0.8140 - val_accuracy: 0.7327 - lr: 1.0000e-04
# Epoch 15/30
# 470/487 [===========================>..] - ETA: 0s - loss: 0.8067 - accuracy: 0.7344
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 15: val_loss improved from 0.81395 to 0.80533, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 15: val_loss improved from 0.81395 to 0.80533, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 15: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.8063 - accuracy: 0.7345 - val_loss: 0.8053 - val_accuracy: 0.7342 - lr: 1.0000e-04
# Epoch 16/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7981 - accuracy: 0.7361
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 16: val_loss improved from 0.80533 to 0.79786, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 16: val_loss improved from 0.80533 to 0.79786, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 16: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7981 - accuracy: 0.7361 - val_loss: 0.7979 - val_accuracy: 0.7360 - lr: 1.0000e-04
# Epoch 17/30
# 477/487 [============================>.] - ETA: 0s - loss: 0.7909 - accuracy: 0.7377
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 17: val_loss improved from 0.79786 to 0.79125, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 17: val_loss improved from 0.79786 to 0.79125, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 17: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7910 - accuracy: 0.7377 - val_loss: 0.7912 - val_accuracy: 0.7377 - lr: 1.0000e-04
# Epoch 18/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7845 - accuracy: 0.7392
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 18: val_loss improved from 0.79125 to 0.78608, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 18: val_loss improved from 0.79125 to 0.78608, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 18: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7846 - accuracy: 0.7392 - val_loss: 0.7861 - val_accuracy: 0.7385 - lr: 1.0000e-04
# Epoch 19/30
# 476/487 [============================>.] - ETA: 0s - loss: 0.7797 - accuracy: 0.7403
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 19: val_loss improved from 0.78608 to 0.78137, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 19: val_loss improved from 0.78608 to 0.78137, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 19: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7795 - accuracy: 0.7404 - val_loss: 0.7814 - val_accuracy: 0.7399 - lr: 1.0000e-04
# Epoch 20/30
# 477/487 [============================>.] - ETA: 0s - loss: 0.7751 - accuracy: 0.7413
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 20: val_loss improved from 0.78137 to 0.77709, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 20: val_loss improved from 0.78137 to 0.77709, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 20: saving model to model_5/KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model_5/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7751 - accuracy: 0.7413 - val_loss: 0.7771 - val_accuracy: 0.7411 - lr: 1.0000e-04
# Epoch 21/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7708 - accuracy: 0.7427
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 21: val_loss improved from 0.77709 to 0.77305, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 21: val_loss improved from 0.77709 to 0.77305, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 21: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7708 - accuracy: 0.7427 - val_loss: 0.7731 - val_accuracy: 0.7416 - lr: 1.0000e-04
# Epoch 22/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.7670 - accuracy: 0.7436
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 22: val_loss improved from 0.77305 to 0.77049, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 22: val_loss improved from 0.77305 to 0.77049, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 22: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7669 - accuracy: 0.7436 - val_loss: 0.7705 - val_accuracy: 0.7422 - lr: 1.0000e-04
# Epoch 23/30
# 476/487 [============================>.] - ETA: 0s - loss: 0.7643 - accuracy: 0.7442
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 23: val_loss improved from 0.77049 to 0.76706, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 23: val_loss improved from 0.77049 to 0.76706, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 23: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7640 - accuracy: 0.7443 - val_loss: 0.7671 - val_accuracy: 0.7433 - lr: 1.0000e-04
# Epoch 24/30
# 473/487 [============================>.] - ETA: 0s - loss: 0.7614 - accuracy: 0.7450
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 24: val_loss improved from 0.76706 to 0.76426, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 24: val_loss improved from 0.76706 to 0.76426, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 24: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7615 - accuracy: 0.7449 - val_loss: 0.7643 - val_accuracy: 0.7442 - lr: 1.0000e-04
# Epoch 25/30
# 485/487 [============================>.] - ETA: 0s - loss: 0.7587 - accuracy: 0.7457
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 25: val_loss improved from 0.76426 to 0.76239, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 25: val_loss improved from 0.76426 to 0.76239, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 25: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7586 - accuracy: 0.7458 - val_loss: 0.7624 - val_accuracy: 0.7442 - lr: 1.0000e-04
# Epoch 26/30
# 486/487 [============================>.] - ETA: 0s - loss: 0.7568 - accuracy: 0.7462
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 26: val_loss improved from 0.76239 to 0.76026, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 26: val_loss improved from 0.76239 to 0.76026, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 26: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7569 - accuracy: 0.7461 - val_loss: 0.7603 - val_accuracy: 0.7450 - lr: 1.0000e-04
# Epoch 27/30
# 476/487 [============================>.] - ETA: 0s - loss: 0.7552 - accuracy: 0.7467
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 27: val_loss improved from 0.76026 to 0.75873, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 27: val_loss improved from 0.76026 to 0.75873, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 27: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 5ms/step - loss: 0.7549 - accuracy: 0.7468 - val_loss: 0.7587 - val_accuracy: 0.7456 - lr: 1.0000e-04
# Epoch 28/30
# 476/487 [============================>.] - ETA: 0s - loss: 0.7530 - accuracy: 0.7473
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 28: val_loss improved from 0.75873 to 0.75716, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 28: val_loss improved from 0.75873 to 0.75716, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 28: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 5ms/step - loss: 0.7532 - accuracy: 0.7473 - val_loss: 0.7572 - val_accuracy: 0.7458 - lr: 1.0000e-04
# Epoch 29/30
# 483/487 [============================>.] - ETA: 0s - loss: 0.7516 - accuracy: 0.7478
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 29: val_loss improved from 0.75716 to 0.75498, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 29: val_loss improved from 0.75716 to 0.75498, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 29: saving model to model_5/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7516 - accuracy: 0.7477 - val_loss: 0.7550 - val_accuracy: 0.7465 - lr: 1.0000e-04
# Epoch 30/30
# 479/487 [============================>.] - ETA: 0s - loss: 0.7500 - accuracy: 0.7480
# ***callbacks***
# saving losses to model_5/losses.log
#
# Epoch 30: val_loss improved from 0.75498 to 0.75359, saving model to model_5/KERAS_check_best_model.h5
#
# Epoch 30: val_loss improved from 0.75498 to 0.75359, saving model to model_5/KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model_5/KERAS_check_model_last.h5
#
# Epoch 30: saving model to model_5/KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model_5/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 487/487 [==============================] - 2s 4ms/step - loss: 0.7498 - accuracy: 0.7482 - val_loss: 0.7536 - val_accuracy: 0.7471 - lr: 1.0000e-04
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Check performance
# How does this model which was trained using 6-bits, and 75% sparsity model compare against the original model? Let's report the accuracy and make a ROC curve. The quantized, pruned model is shown with solid lines, the unpruned original model is shown with dashed lines.
#
#
# We can also check that this performance isn't specific to some special setup in QKeras. We will use hls4ml can respect the choice to use 6-bits throughout the model, and match the accuracy. We'll generate a configuration from this Quantized model, and plot its performance as the dotted line.
# The generated configuration is printed out. You'll notice that it uses 7 bits for the type, but we specified 6!? That's just because QKeras doesn't count the sign-bit when we specify the number of bits, so the type that actually gets used needs 1 more.
#
# We also use the `OutputRoundingSaturationMode` optimizer pass of `hls4ml` to set the Activation layers to round, rather than truncate, the cast. This is important for getting good model accuracy when using small bit precision activations. And we'll set a different data type for the tables used in the Softmax, just for a bit of extra performance.

# %%
import hls4ml
import plotting

hls4ml.model.optimizer.get_optimizer("output_rounding_saturation_mode").layers = [
    "Activation"
]
hls4ml.model.optimizer.get_optimizer(
    "output_rounding_saturation_mode"
).rounding_mode = "AP_RND"
hls4ml.model.optimizer.get_optimizer(
    "output_rounding_saturation_mode"
).saturation_mode = "AP_SAT"

config = hls4ml.utils.config_from_keras_model(
    model, granularity="name", default_precision="ap_fixed<10,4>"
)
config["LayerName"]["softmax"]["exp_table_t"] = "ap_fixed<18,8>"
config["LayerName"]["softmax"]["inv_table_t"] = "ap_fixed<18,4>"
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(
    model,
    hls_config=config,
    output_dir="model_5/hls4ml_prj",
    part="xcu250-figd2104-2L-e",
)
hls_model.compile()

y_qkeras = model.predict(np.ascontiguousarray(X_test))
y_hls = hls_model.predict(np.ascontiguousarray(X_test))
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: Input
# Layer name: fc1, layer type: QDense
#   -> Activation (linear), layer name: fc1
# Layer name: relu1, layer type: QActivation
#   -> Activation (quantized_relu), layer name: relu1
# Layer name: fc2, layer type: QDense
#   -> Activation (linear), layer name: fc2
# Layer name: relu2, layer type: QActivation
#   -> Activation (quantized_relu), layer name: relu2
# Layer name: fc3, layer type: QDense
#   -> Activation (linear), layer name: fc3
# Layer name: relu3, layer type: QActivation
#   -> Activation (quantized_relu), layer name: relu3
# Layer name: output, layer type: QDense
#   -> Activation (linear), layer name: output
# Layer name: softmax, layer type: Activation
# -----------------------------------
# Model
#   Precision:         ap_fixed<10,4>
#   ReuseFactor:       1
#   Strategy:          Latency
# LayerName
#   fc1_input
#     Precision
#       result:        ap_fixed<10,4>
#   fc1
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   fc1_linear
#     Precision:       ap_fixed<10,4>
#     ReuseFactor:     1
#     table_size:      1024
#     table_t:         ap_fixed<18,8>
#   relu1
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   relu1_quantized_relu
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc2
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   fc2_linear
#     Precision:       ap_fixed<10,4>
#     ReuseFactor:     1
#     table_size:      1024
#     table_t:         ap_fixed<18,8>
#   relu2
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   relu2_quantized_relu
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   fc3
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   fc3_linear
#     Precision:       ap_fixed<10,4>
#     ReuseFactor:     1
#     table_size:      1024
#     table_t:         ap_fixed<18,8>
#   relu3
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   relu3_quantized_relu
#     Precision
#       result:        ap_ufixed<6,0>
#     ReuseFactor:     1
#   output
#     Precision
#       weight:        ap_fixed<6,1>
#       bias:          ap_fixed<6,1>
#     ReuseFactor:     1
#   output_linear
#     Precision:       ap_fixed<10,4>
#     ReuseFactor:     1
#     table_size:      1024
#     table_t:         ap_fixed<18,8>
#   softmax
#     Precision:       ap_fixed<10,4>
#     ReuseFactor:     1
#     table_size:      1024
#     exp_table_t:     ap_fixed<18,8>
#     inv_table_t:     ap_fixed<18,4>
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 16]], output shape: [None, 64]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 64]], output shape: [None, 32]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: relu3, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: output, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 5]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 5]], output shape: [None, 5]
# Creating HLS model
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
# 5188/5188 [==============================] - 4s 730us/step

# %%
# %matplotlib inline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

if not COLAB:
    model_ref = load_model("model_1/KERAS_check_best_model.h5") #locally
else:
    model_ref = load_model("iaifi-summer-school/book/model_1/KERAS_check_best_model.h5") #for colab

y_ref = model_ref.predict(X_test)

print(
    "Accuracy baseline:  {}".format(
        accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))
    )
)
print(
    "Accuracy pruned, quantized: {}".format(
        accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))
    )
)
print(
    "Accuracy hls4ml: {}".format(
        accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))
    )
)

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_qkeras, classes, linestyle="--")
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_hls, classes, linestyle=":")

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls="-"), Line2D([0], [0], ls="--"), Line2D([0], [0], ls=":")]
from matplotlib.legend import Legend

leg = Legend(
    ax,
    lines,
    labels=["baseline", "pruned, quantized", "hls4ml"],
    loc="lower right",
    frameon=False,
)
ax.add_artist(leg)
# Out:
# 5188/5188 [==============================] - 3s 577us/step
# Accuracy baseline:  0.7516506024096385
# Accuracy pruned, quantized: 0.7460240963855421
# Accuracy hls4ml: 0.7423975903614458
